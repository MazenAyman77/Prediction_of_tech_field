# %%
import mlflow
from mlflow.tracking import MlflowClient

import pandas as pd

# %%
mlflow.set_tracking_uri('../models/mlruns')
client = MlflowClient()

# %%
experiment = client.get_experiment_by_name('skills_jobs_stackoverflow')
experiment
# Out:
# <Experiment: artifact_location=('file:///C:/Users/master/iti skills '
#  'project/notebooks/../models/mlruns/913210138784205209'), creation_time=1695829434693, experiment_id='913210138784205209', last_update_time=1695829434693, lifecycle_stage='active', name='skills_jobs_stackoverflow', tags={}>

# %%
runs = mlflow.search_runs([experiment.experiment_id])
runs
# Out:
#                              run_id       experiment_id    status  \
# 0  4f759fd904714f5690594a453b6a8002  913210138784205209  FINISHED
# 1  c29982e0857e4e8da661fa400d108cc6  913210138784205209    FAILED
# 2  1441604ce1944c54847a034875470678  913210138784205209  FINISHED
# 3  39a4d6ca6e1a467eb33af8d8ab4764de  913210138784205209  FINISHED
# 4  d286a89145a5439d8ee42f35b14cf6b1  913210138784205209  FINISHED
#
#                                         artifact_uri  \
# 0  file:///C:/Users/master/iti skills project/not...
# 1  file:///C:/Users/master/iti skills project/not...
# 2  file:///C:/Users/master/iti skills project/not...
# 3  file:///C:/Users/master/iti skills project/not...
# 4  file:///C:/Users/master/iti skills project/not...
#
#                         start_time                         end_time  \
# 0 2023-09-29 12:58:34.073000+00:00 2023-09-29 12:58:41.180000+00:00
# 1 2023-09-29 12:58:18.445000+00:00 2023-09-29 12:58:18.600000+00:00
# ...
